# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime

# %%
#1
df_data = pd.read_excel('airlines.xlsx', parse_dates=['Date_of_Journey'])
df_data
# Out:
# C:\Users\lordd\AppData\Local\Temp\ipykernel_4116\4172167529.py:2: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df_data = pd.read_excel('airlines.xlsx', parse_dates=['Date_of_Journey'])
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# 4           IndiGo      2019-03-01  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-03-01  Banglore   New Delhi
# ...

# %%
#2

df_data = df_data.dropna()

# %%
#3

df_data.isnull().values.any()
# Out:
# False

# %%
#4

df_data['Date_of_Journey'] = pd.to_datetime(df_data['Date_of_Journey'])
df_data['Dep_Time'] = pd.to_datetime(df_data['Dep_Time'])
df_data['Arrival_Time'] = pd.to_datetime(df_data['Arrival_Time'])

df_data.dtypes
# Out:
# C:\Users\lordd\AppData\Local\Temp\ipykernel_4116\3612293248.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Date_of_Journey'] = pd.to_datetime(df_data['Date_of_Journey'])
# C:\Users\lordd\AppData\Local\Temp\ipykernel_4116\3612293248.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df_data['Dep_Time'] = pd.to_datetime(df_data['Dep_Time'])
# C:\Users\lordd\AppData\Local\Temp\ipykernel_4116\3612293248.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#5

## date

jDay = df_data['Date_of_Journey'].dt.day
jMonth = df_data['Date_of_Journey'].dt.month
jYear = df_data['Date_of_Journey'].dt.year

df_data['Journey_day'] = jDay
df_data['Journey_month'] = jMonth
df_data['Journey_year'] = jYear

## time

dHour = df_data['Dep_Time'].dt.hour
dMinute = df_data['Dep_Time'].dt.minute

aHour = df_data['Arrival_Time'].dt.hour
aMinute = df_data['Arrival_Time'].dt.minute

df_data['Dep_Time_hour'] = dHour
df_data['Dep_Time_minute'] = dMinute
df_data['Arrival_Time_hour'] = aHour
df_data['Arrival_Time_minute'] = aMinute

df_data.dtypes
# Out:
# C:\Users\lordd\AppData\Local\Temp\ipykernel_4116\746181135.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Journey_day'] = jDay
# C:\Users\lordd\AppData\Local\Temp\ipykernel_4116\746181135.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Journey_month'] = jMonth
# C:\Users\lordd\AppData\Local\Temp\ipykernel_4116\746181135.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
#6

def giveDescription(time):

    if (time >= 4 and time < 8):
        return 'Early Morning'

    elif (time >= 8 and time < 12):
        return 'Morning'

    if (time >= 12 and time < 16):
        return 'Noon'

    if (time >= 16 and time < 18):
        return 'Evening'

    if (time >= 18 and time < 24):
        return 'Night'

    elif (time >= 0 and time < 4):
        return 'Late Night'

desc = df_data['Dep_Time_hour'].apply(giveDescription)
df_data['dep_description'] = desc
df_data
# Out:
# C:\Users\lordd\AppData\Local\Temp\ipykernel_4116\3096378341.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['dep_description'] = desc
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# 4           IndiGo      2019-03-01  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# ...

# %%
#8

xAxis = df_data['dep_description'].drop_duplicates()
yAxis = df_data['dep_description'].value_counts()

plt.bar(xAxis, yAxis)
# Out:
# <BarContainer object of 6 artists>

# %%
#9
dHour = df_data['Duration'].str.extract('(\d+)h', expand=False).astype(float) * 60
dMin = df_data['Duration'].str.extract('(\d+)m', expand=False).astype(float)

df_data['Duration_Total_mins'] = dHour.add(dMin, fill_value=0).astype(int)
df_data['Duration_hours'] = dHour/60
df_data['Duration_mins'] = dMin
# Out:
# C:\Users\lordd\AppData\Local\Temp\ipykernel_4116\210766836.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Duration_Total_mins'] = dHour.add(dMin, fill_value=0).astype(int)
# C:\Users\lordd\AppData\Local\Temp\ipykernel_4116\210766836.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['Duration_hours'] = dHour/60
# C:\Users\lordd\AppData\Local\Temp\ipykernel_4116\210766836.py:7: SettingWithCopyWarning:
# ...

# %%
#10

df_data
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      2019-03-24  Banglore   New Delhi
# 1        Air India      2019-05-01   Kolkata    Banglore
# 2      Jet Airways      2019-06-09     Delhi      Cochin
# 3           IndiGo      2019-05-12   Kolkata    Banglore
# 4           IndiGo      2019-03-01  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10678     Air Asia      2019-04-09   Kolkata    Banglore
# 10679    Air India      2019-04-27   Kolkata    Banglore
# 10680  Jet Airways      2019-04-27  Banglore       Delhi
# 10681      Vistara      2019-03-01  Banglore   New Delhi
# 10682    Air India      2019-05-09     Delhi      Cochin
#
#                        Route            Dep_Time        Arrival_Time Duration  \
# 0                  BLR → DEL 2024-05-18 22:20:00 2024-03-22 01:10:00   2h 50m
# 1      CCU → IXR → BBI → BLR 2024-05-18 05:50:00 2024-05-18 13:15:00   7h 25m
# ...

# %%
#10

xAxis = df_data['Duration_Total_mins']
yAxis = df_data['Price']

plt.scatter(xAxis, yAxis)
